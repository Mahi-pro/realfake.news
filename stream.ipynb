# %%
# !pip install streamlit pyngrok --quiet

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-4f67b558-cffd-4d5f-8270-9f259689b7fa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f67b558-cffd-4d5f-8270-9f259689b7fa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install dependencies
# !pip install streamlit pyngrok --quiet

# Write your Streamlit app to app.py
app_code = '''
import streamlit as st
import pickle

# Load model and vectorizer
model = pickle.load(open("logistic_model.pkl", "rb"))
vectorizer = pickle.load(open("tfidf_vectorizer.pkl", "rb"))

st.title("📰 Fake News Detection App")
st.markdown("Paste a news article or headline below and find out whether it's **Fake** or **Real**.")

input_text = st.text_area("Enter News Text:", height=200)

if st.button("Detect"):
    if input_text.strip() == "":
        st.warning("Please enter some news text.")
    else:
        text_vector = vectorizer.transform([input_text])
        prediction = model.predict(text_vector)[0]
        if prediction == 0:
            st.error("🔴 This news seems **FAKE**.")
        else:
            st.success("🟢 This news seems **REAL**.")
'''

# Save it as app.py
with open("app.py", "w") as f:
    f.write(app_code)

# Set up ngrok
from pyngrok import ngrok
ngrok.set_auth_token("2uhh33g1xYfI0SiVjx3niDVnDYV_6UfjSRzaRMSu8bHf7FDxb")

# Run Streamlit in background
import subprocess
process = subprocess.Popen(["streamlit", "run", "app.py"])

# Wait a moment then tunnel
import time
time.sleep(5)
public_url = ngrok.connect(8501)
print("🚀 Your app is live at:", public_url)
# Out:
# 🚀 Your app is live at: NgrokTunnel: "https://5d1a-34-16-219-11.ngrok-free.app" -> "http://localhost:8501"
